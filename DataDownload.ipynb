# %%
cd /content/drive/Shareddrives/개별연구/saram1118
# Out:
# /content/drive/Shareddrives/개별연구/saram1118

# %%
cd OIDv4_ToolKit/
# Out:
# /content/drive/Shareddrives/개별연구/saram1118/OIDv4_ToolKit

# %% [markdown]
# # 처음 작업할 때만 다운로드

# %%
# !git clone https://github.com/theAIGuysCode/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 444, done.
# remote: Total 444 (delta 0), reused 0 (delta 0), pack-reused 444
# Receiving objects: 100% (444/444), 34.09 MiB | 10.91 MiB/s, done.
# Resolving deltas: 100% (157/157), done.

# %% [markdown]
# # 데이터 다운받기
#
# [데이터 다운로드](https://storage.googleapis.com/openimages/web/index.html)

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 3.5MB 5.3MB/s
# ...
#      |████████████████████████████████| 71kB 7.1MB/s
# ...
#      |████████████████████████████████| 552kB 31.6MB/s
# ...
#      |████████████████████████████████| 6.9MB 36.7MB/s
# ...
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: botocore 1.19.25 has requirement urllib3<1.27,>=1.25.4; python_version != "3.4", but you'll have urllib3 1.24.3 which is incompatible.
# ...
#   Found existing installation: rsa 4.6
#     Uninstalling rsa-4.6:
#       Successfully uninstalled rsa-4.6
#   Found existing installation: docutils 0.16
#     Uninstalling docutils-0.16:
#       Successfully uninstalled docutils-0.16
# ...

# %%
# !python main.py downloader --classes Human\ body --type_csv train --limit 1500
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Human body.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...145%, 0 MB, 35171 KB/s, 0 seconds passed
# ...

# %% [markdown]
# # 90도 돌린 (jpg,txt) 처리
#
# 1. **이미지 돌리기 전에:**
#
#   "Person"이랑 같은 디렉토리에 "Person_90"폴더 만들기-코드보면 자세한 경로 있음
#
# 2. **txt설정하기 전에:**
#
#   파이썬 파일들 실행하기전에 Person/Label안에 Label_90폴더 만들어 주기-위에서 Person_90 만들때 해도 됨 --> human body와 같은 경우 클래스 이름이 띄어쓰기로 구분되어 있어서 txt파일 설정시 클래스 이름이 하나인 것과 코드가 다름

# %% [markdown]
# ```
# function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-toolbar-button#connect").click()
# }
# setInterval(ClickConnect,60000)
#
# ```

# %%
# !python turn_image.py
# Out:
# 100% 236/236 [06:16<00:00,  1.59s/it]

# %% [markdown]
# classes.txt 일부러 이름 다르게 해서 인식안되게 꼼수 ㄱ ㄱ

# %%
# !python txt_90.py
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Human body
#   0% 0/237 [00:00<?, ?it/s]20c2d8cafda46064
# 20c2d8cafda46064
# 20c2d8cafda46064
#   0% 1/237 [00:00<03:18,  1.19it/s]8c05802e9f76d544
#   1% 2/237 [00:01<03:22,  1.16it/s]7ebaf1dcf495f452
# 7ebaf1dcf495f452
# 7ebaf1dcf495f452
# 7ebaf1dcf495f452
# 7ebaf1dcf495f452
#   1% 3/237 [00:02<03:28,  1.12it/s]8e36a0d0b8747448
# 8e36a0d0b8747448
#   2% 4/237 [00:04<04:07,  1.06s/it]15bb7f2ff130d4cc
#   2% 5/237 [00:05<04:26,  1.15s/it]50e7fbcd5602cff0
# 50e7fbcd5602cff0
# 50e7fbcd5602cff0
# 50e7fbcd5602cff0
# 50e7fbcd5602cff0
# 50e7fbcd5602cff0
# 50e7fbcd5602cff0
# 50e7fbcd5602cff0
# 50e7fbcd5602cff0
# 50e7fbcd5602cff0
# 50e7fbcd5602cff0
# 50e7fbcd5602cff0
#   3% 6/237 [00:07<04:54,  1.28s/it]7e89faa5d43dd015
#   3% 7/237 [00:08<04:57,  1.29s/it]49a01359aed93b4c
#   3% 8/237 [00:09<05:00,  1.31s/it]34d7f688eb9954a6
#   4% 9/237 [00:11<05:06,  1.34s/it]8aaa2b817fb9fd06
# 8aaa2b817fb9fd06
# ...

# %%
# !python txt_90_lr.py
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Human body
# 100% 237/237 [00:15<00:00, 14.88it/s]
# Converting annotations for class:  Person_90
# Traceback (most recent call last):
#   File "txt_90_lr.py", line 51, in <module>
#     os.chdir("Label")
# FileNotFoundError: [Errno 2] No such file or directory: 'Label'

# %%
# !python txt_90_ud.py
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Human body
# 100% 237/237 [00:15<00:00, 14.83it/s]
# Converting annotations for class:  Person_90
# Traceback (most recent call last):
#   File "txt_90_ud.py", line 51, in <module>
#     os.chdir("Label")
# FileNotFoundError: [Errno 2] No such file or directory: 'Label'

# %%
# !python txt_90_udlr.py
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Human body
# 100% 237/237 [00:15<00:00, 14.95it/s]
# Converting annotations for class:  Person_90
# Traceback (most recent call last):
#   File "txt_90_udlr.py", line 51, in <module>
#     os.chdir("Label")
# FileNotFoundError: [Errno 2] No such file or directory: 'Label'

# %% [markdown]
# # 욜로에 맞게 TXT파일 변환 JPG파일
#
# convert_annotations.py돌리기 전에 Person/Label에 있는 Label_90폴더 Person_90폴더에 넣고 이름 Label로 바꾸고 돌리기
#
# **classes.txt 바꾸는거 잊지말기**: 다운로드 받은 클래스 이름과 똑같이 저장되어야 함

# %%
ls
# Out:
# classes.txt                   LICENSE   README.md         txt_90.py
# convert_annotations.py        main.py   requirements.txt  txt_90_udlr.py
# convert_annotations_stand.py  modules/  turn_image.py     txt_90_ud.py
# images/                       OID/      txt_90_lr.py

# %%
# !python convert_annotations.py
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Human body
# 100% 236/236 [00:16<00:00, 14.24it/s]
# Converting annotations for class:  Person_90
# 100% 944/944 [00:56<00:00, 16.81it/s]

# %%
# !python convert_annotations_stand.py
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Human body
# 100% 236/236 [00:15<00:00, 14.85it/s]
